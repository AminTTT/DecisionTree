# %%
import numpy
import pandas
from google.colab import files

# %%
# to use upload file:
#uploaded = files.upload()
#df = pandas.read_csv('DecisionTree.csv')

# %%
# or you can use 'mount with google Drive' and link to arbitrary file:
from google.colab import drive
drive.mount('/content/drive')
df = pandas.read_csv("/content/drive/MyDrive/send_To_githab/DecisionTree.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(df)
# Out:
#    Education_town  Work_experience  Article  Morality Gendering   Go
# 0         Chicago               10        5        15       man  yes
# 1           Miami               15        3        15       man  yes
# 2          Dallas                5        2        16     woman  yes
# 3         Atlanta                7        5        12     woman   no
# 4         Atlanta                4       10        13     woman  yes
# 5          Boston               14        2        19       man  yes
# 6          Denver                5        5        11     woman   no
# 7           Miami                3        0        18       man  yes
# 8         Atlanta                6        1        13     woman   no
# 9          Boston               20        7        14       man   no
# 10         Dallas               11        1        13     woman   no
# 11        Chicago               16        3        15       man   no
# 12          Miami                5        7        13     woman  yes
# ...

# %%
# روی مطابقت عینی حروف و کلمات از لحاظ بزرگی و کوچکی حروف بین اکسل و دستورات زیر دقت شود
d = {'Chicago': 0, 'Miami': 1, 'Dallas': 2, 'Atlanta': 3, 'Boston': 4, 'Denver': 5}
df['Education_town'] = df['Education_town'].map(d)

d = {'man': 1, 'woman': 0}
df['Gendering'] = df['Gendering'].map(d)
d = {'yes': 1, 'no': 0}
df['Go'] = df['Go'].map(d)
print(df)
# Out:
#     Education_town  Work_experience  Article  Morality  Gendering  Go
# 0                0               10        5        15          1   1
# 1                1               15        3        15          1   1
# 2                2                5        2        16          0   1
# 3                3                7        5        12          0   0
# 4                3                4       10        13          0   1
# 5                4               14        2        19          1   1
# 6                5                5        5        11          0   0
# 7                1                3        0        18          1   1
# 8                3                6        1        13          0   0
# 9                4               20        7        14          1   0
# 10               2               11        1        13          0   0
# 11               0               16        3        15          1   0
# ...

# %%
features = ['Education_town', 'Work_experience', 'Article', 'Morality', 'Gendering']

X = df[features]
y = df['Go']

print(X)
print(y)
# Out:
#     Education_town  Work_experience  Article  Morality  Gendering
# 0                0               10        5        15          1
# 1                1               15        3        15          1
# 2                2                5        2        16          0
# 3                3                7        5        12          0
# 4                3                4       10        13          0
# 5                4               14        2        19          1
# 6                5                5        5        11          0
# 7                1                3        0        18          1
# 8                3                6        1        13          0
# 9                4               20        7        14          1
# 10               2               11        1        13          0
# 11               0               16        3        15          1
# 12               1                5        7        13          0
# ...

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)
tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.28125, 0.9375, 'Article <= 1.5\ngini = 0.498\nsamples = 34\nvalue = [16, 18]'),
#  Text(0.125, 0.8125, 'Morality <= 17.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.0625, 0.6875, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.1875, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4375, 0.8125, 'Morality <= 12.5\ngini = 0.466\nsamples = 27\nvalue = [10, 17]'),
#  Text(0.3125, 0.6875, 'Work_experience <= 14.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.25, 0.5625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.375, 0.5625, 'Gendering <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3125, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4375, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5625, 0.6875, 'Work_experience <= 3.5\ngini = 0.346\nsamples = 18\nvalue = [4, 14]'),
#  Text(0.5, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
# ...

# %%
print(dtree.predict([[0, 5, 8, 12,0]]))
# Out:
# [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
